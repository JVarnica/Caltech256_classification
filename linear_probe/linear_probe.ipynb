# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/caltech_proj/data/dt_split_new.py
# Out:
# Starting dataset split...
# Source directory: /content/drive/MyDrive/caltech_proj/data/256_ObjectCategories
# Output directory: /content/drive/MyDrive/caltech_proj/data/Caltech256_Split
# Processing classes: 100% 256/256 [1:07:57<00:00, 15.93s/it]
# Dataset split completed successfully!

# %%
# !python /content/drive/MyDrive/caltech_proj/data/mock_dataset.py
# Out:
# Creating mock training dataset...
#
# Creating mock validation dataset...
#
# Mock datasets created successfully!
# Mock training data: /content/drive/MyDrive/caltech_proj/data/Caltech256_Split/mock_data/mock_train
# Mock validation data: /content/drive/MyDrive/caltech_proj/data/Caltech256_Split/mock_data/mock_val

# %%
pip install nvidia-dali-cuda120

# %%
pip install timm

# %%
# !nvidia-smi
import torch
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
print("GPU device:", torch.cuda.get_device_name(0))
# Out:
# Wed Aug 14 13:02:32 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA L4                      Off | 00000000:00:03.0 Off |                    0 |
# | N/A   35C    P8              11W /  72W |      1MiB / 23034MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !python /content/drive/MyDrive/caltech_proj/experiments/model_arc.py
# Out:
# Inspecting model: resnet50.a1_in1k
# Model type: ResNet
# 'fc' attribute found: Linear(in_features=2048, out_features=1000, bias=True)
# No 'head' attribute found
#
# Last few layers:
# layer4.2.act3: ReLU(inplace=True)
# global_pool: SelectAdaptivePool2d(pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
# global_pool.pool: AdaptiveAvgPool2d(output_size=1)
# global_pool.flatten: Flatten(start_dim=1, end_dim=-1)
# fc: Linear(in_features=2048, out_features=1000, bias=True)
#
# Possible classification head identified: Linear(in_features=2048, out_features=1000, bias=True)
# Input features: 2048
# Output features: 1000
#
# ...
#
# Inspection complete.

# %%
import os

def count_images(directory):
    image_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.gif')
    total_images = 0

    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.lower().endswith(image_extensions):
                total_images += 1

    return total_images

train_dir = '/content/drive/MyDrive/caltech_proj/data/Cifar100/train'
val_dir = '/content/drive/MyDrive/caltech_proj/data/Cifar100/val'
test_dir = '/content/drive/MyDrive/caltech_proj/data/Cifar100/test'
train_images = count_images(train_dir)
val_images = count_images(val_dir)
test_images = count_images(test_dir)

print(f"Total images in training set: {train_images}")
print(f"Total images in validation set: {val_images}")
print(f"Total images in test set: {test_images}")
# Out:
# Total images in training set: 43721
# Total images in validation set: 6260
# Total images in test set: 10000

# %%
# !python /content/drive/MyDrive/cifar100_datasplit.py
# Out:
# Extraction complete

# %%
# !pip install nvidia-nvjpeg2k-cu12
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 4.0 MB/s eta 0:00:00
# ...

# %%
! python /content/drive/MyDrive/caltech_proj/linear_probe/model_eval.py mock_data
# Out:
# Added to sys.path: /content/drive/MyDrive/caltech_proj
# Starting Experiment on mock_data...
# Training and evaluating pvt_v2_b3.in1k
# Epoch 1/2, Train Loss: 5.6301, Train Acc: 0.0125,Val Loss: 5.5533, Val Acc: 0.0000,Time: 0.77s
# Epoch 2/2, Train Loss: 5.3216, Train Acc: 0.0250,Val Loss: 5.4365, Val Acc: 0.0000,Time: 0.43s
#
# Training completed for pvt_v2_b3.in1k
# Final validation accuracy: 0.0000
# Total training time: 4.64 seconds
# ---
# Model figure saved
# Training and evaluating vit_base_patch16_224.orig_in21k_ft_in1k
# Epoch 1/2, Train Loss: 5.5736, Train Acc: 0.0000,Val Loss: 5.0521, Val Acc: 0.0250,Time: 0.53s
# Epoch 2/2, Train Loss: 4.9519, Train Acc: 0.0125,Val Loss: 4.5490, Val Acc: 0.0250,Time: 0.57s
#
# Training completed for vit_base_patch16_224.orig_in21k_ft_in1k
# Final validation accuracy: 0.0250
# Total training time: 2.03 seconds
# ---
# Model figure saved
# Training and evaluating deit3_base_patch16_224.fb_in22k_ft_in1k
# ...

# %%
! python /content/drive/MyDrive/caltech_proj/linear_probe/model_eval.py lp_caltech256
# Out:
# Added to sys.path: /content/drive/MyDrive/caltech_proj
# Starting Experiment on lp_caltech256...
# Training and evaluating pvt_v2_b3.in1k
# Epoch 1/5, Train Loss: 3.1481, Train Acc: 0.5054,Val Loss: 1.6187, Val Acc: 0.7004,Time: 188.94s
# Epoch 2/5, Train Loss: 1.2483, Train Acc: 0.7540,Val Loss: 1.1749, Val Acc: 0.7492,Time: 92.55s
# Epoch 3/5, Train Loss: 0.9178, Train Acc: 0.8008,Val Loss: 1.0458, Val Acc: 0.7620,Time: 92.61s
# Epoch 4/5, Train Loss: 0.7571, Train Acc: 0.8328,Val Loss: 0.9802, Val Acc: 0.7718,Time: 92.53s
# Epoch 5/5, Train Loss: 0.6479, Train Acc: 0.8558,Val Loss: 0.9456, Val Acc: 0.7711,Time: 92.50s
#
# Training completed for pvt_v2_b3.in1k
# Final validation accuracy: 0.7718
# Total training time: 655.80 seconds
# ---
# Model figure saved
# Training and evaluating vit_base_patch16_224.orig_in21k_ft_in1k
# Epoch 1/5, Train Loss: 5.2126, Train Acc: 0.0603,Val Loss: 4.9067, Val Acc: 0.0953,Time: 117.33s
# ...

# %%
! python /content/drive/MyDrive/caltech_proj/linear_probe/model_eval.py lp_cifar100
# Out:
# Added to sys.path: /content/drive/MyDrive/caltech_proj
# Starting Experiment on lp_cifar100...
# Training and evaluating pvt_v2_b3.in1k
# Epoch 1/5, Train Loss: 2.9616, Train Acc: 0.3147,Val Loss: 2.3305, Val Acc: 0.4173,Time: 336.30s
# Epoch 2/5, Train Loss: 2.2038, Train Acc: 0.4423,Val Loss: 2.0970, Val Acc: 0.4561,Time: 192.34s
# Epoch 3/5, Train Loss: 2.0152, Train Acc: 0.4809,Val Loss: 2.0095, Val Acc: 0.4796,Time: 192.54s
# Epoch 4/5, Train Loss: 1.9042, Train Acc: 0.5049,Val Loss: 1.9352, Val Acc: 0.4947,Time: 192.66s
# Epoch 5/5, Train Loss: 1.8294, Train Acc: 0.5224,Val Loss: 1.8806, Val Acc: 0.5059,Time: 192.48s
#
# Training completed for pvt_v2_b3.in1k
# Final validation accuracy: 0.5059
# Total training time: 1194.28 seconds
# ---
# Model figure saved
# Training and evaluating vit_base_patch16_224.orig_in21k_ft_in1k
# Epoch 1/5, Train Loss: 4.0823, Train Acc: 0.0854,Val Loss: 3.8384, Val Acc: 0.1249,Time: 244.50s
# ...
